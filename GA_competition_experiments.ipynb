# %%
import numpy as np
import pandas as pd
import time
import random
import os
import re
import json
import ast
import seaborn as sns
from helper_functions_assignment2 import*

# %%
folder_path = "data/inst_competition/"
problem_instances = [file.replace('.txt', '') for file in os.listdir(folder_path) if not file == "test.txt"]

# %% [markdown]
# # experiments for GA

# %% [markdown]
# ### run for all best configs from SMAC3

# %%
# read in the file with the best configurations
best_configs = 'GA_smac_results.txt'
with open(best_configs, 'r') as file:
    file_content = file.read()

# Extract configurations using regular expressions
config_pattern = r"Configuration\(values=\{([^}]*)\}\)"
config_values = re.findall(config_pattern, file_content)

# Convert configurations to a list of dictionaries
config_dicts = []
for config_val in config_values:
    config_dict = ast.literal_eval('{' + config_val + '}')
    config_dicts.append(config_dict)

# %%
test_results = []
for c in config_dicts:
    print(c)
    for p in problem_instances:
        print(p)
        path = folder_path+p+".txt"
        node_impact_orig, node_degree_orig, plex_assignment, edges_n1, edges_n2, edge_weights, edge_assignment_orig, s, n, m = create_problem_instance(path)

        start = time.time()
        test = GA(pop_size = c["pop_size"],
                  init_no_plexes = c["init_no_plexes"], 
                  mutate = c["mutate"],
                  elitism_k = c["elitism_k"],
                  MaxStallGenerations = c["MaxStallGenerations"], 
                  tolerance = c["tolerance"], 
                  node_impact_orig = node_impact_orig, 
                  node_degree_orig = node_degree_orig, 
                  edge_assignment_orig = edge_assignment_orig, 
                  edge_weights = edge_weights, 
                  s = s, 
                  trajectory = False)

        test_results.append({"Instance": p,
                             "pop_size": c["pop_size"],
                             "init_no_plexes": c["init_no_plexes"],
                             "mutate": c["mutate"],
                             "elitism_k": c["elitism_k"],
                             "MaxStallGenerations": c["MaxStallGenerations"],
                             "tolerance": c["tolerance"],
                             "result": test, 
                             "baseline": sum(node_impact_orig)/2,
                             "score": test.score, 
                             "runtime": time.time()-start})
# Out:
# {'MaxStallGenerations': 5, 'elitism_k': 2, 'init_no_plexes': 13, 'mutate': False, 'pop_size': 80, 'tolerance': 0.016322987787425518}
# heur049_n_300_m_17695
# time_limit
# heur050_n_300_m_19207
# time_limit
# heur051_n_300_m_20122
# time_limit
# {'MaxStallGenerations': 3, 'elitism_k': 48, 'init_no_plexes': 24, 'mutate': True, 'pop_size': 52, 'tolerance': 0.03496975654736161}
# heur049_n_300_m_17695
# heur050_n_300_m_19207
# heur051_n_300_m_20122
# {'MaxStallGenerations': 1, 'elitism_k': 40, 'init_no_plexes': 19, 'mutate': False, 'pop_size': 59, 'tolerance': 0.0597897171376749}
# heur049_n_300_m_17695
# heur050_n_300_m_19207
# heur051_n_300_m_20122
# {'MaxStallGenerations': 5, 'elitism_k': 36, 'init_no_plexes': 7, 'mutate': False, 'pop_size': 92, 'tolerance': 0.027953616660088304}
# heur049_n_300_m_17695
# time_limit
# heur050_n_300_m_19207
# time_limit
# heur051_n_300_m_20122
# time_limit
# {'MaxStallGenerations': 3, 'elitism_k': 5, 'init_no_plexes': 25, 'mutate': False, 'pop_size': 89, 'tolerance': 0.06295001611113549}
# heur049_n_300_m_17695
# time_limit
# heur050_n_300_m_19207
# time_limit
# heur051_n_300_m_20122
# time_limit
# {'MaxStallGenerations': 1, 'elitism_k': 35, 'init_no_plexes': 19, 'mutate': False, 'pop_size': 60, 'tolerance': 0.059859556483977075}
# heur049_n_300_m_17695
# heur050_n_300_m_19207
# heur051_n_300_m_20122
# {'MaxStallGenerations': 1, 'elitism_k': 36, 'init_no_plexes': 13, 'mutate': False, 'pop_size': 59, 'tolerance': 0.02232652705162764}
# heur049_n_300_m_17695
# heur050_n_300_m_19207
# heur051_n_300_m_20122
# {'MaxStallGenerations': 1, 'elitism_k': 45, 'init_no_plexes': 11, 'mutate': False, 'pop_size': 60, 'tolerance': 0.06012884214167295}
# heur049_n_300_m_17695
# heur050_n_300_m_19207
# heur051_n_300_m_20122
# {'MaxStallGenerations': 1, 'elitism_k': 44, 'init_no_plexes': 11, 'mutate': False, 'pop_size': 60, 'tolerance': 0.021238160228842857}
# heur049_n_300_m_17695
# heur050_n_300_m_19207
# heur051_n_300_m_20122
# {'MaxStallGenerations': 2, 'elitism_k': 38, 'init_no_plexes': 19, 'mutate': False, 'pop_size': 59, 'tolerance': 0.02027818304114496}
# heur049_n_300_m_17695
# heur050_n_300_m_19207
# heur051_n_300_m_20122
# time_limit

# %%
results = pd.DataFrame(test_results)
results["instance_ID"] = results["Instance"].str[4:7]
results
# Out:
#                  Instance  pop_size  init_no_plexes  mutate  elitism_k  \
# 0   heur049_n_300_m_17695        80              13   False          2
# 1   heur050_n_300_m_19207        80              13   False          2
# 2   heur051_n_300_m_20122        80              13   False          2
# 3   heur049_n_300_m_17695        52              24    True         48
# 4   heur050_n_300_m_19207        52              24    True         48
# 5   heur051_n_300_m_20122        52              24    True         48
# 6   heur049_n_300_m_17695        59              19   False         40
# 7   heur050_n_300_m_19207        59              19   False         40
# 8   heur051_n_300_m_20122        59              19   False         40
# 9   heur049_n_300_m_17695        92               7   False         36
# 10  heur050_n_300_m_19207        92               7   False         36
# 11  heur051_n_300_m_20122        92               7   False         36
# 12  heur049_n_300_m_17695        89              25   False          5
# 13  heur050_n_300_m_19207        89              25   False          5
# 14  heur051_n_300_m_20122        89              25   False          5
# 15  heur049_n_300_m_17695        60              19   False         35
# 16  heur050_n_300_m_19207        60              19   False         35
# 17  heur051_n_300_m_20122        60              19   False         35
# 18  heur049_n_300_m_17695        59              13   False         36
# 19  heur050_n_300_m_19207        59              13   False         36
# 20  heur051_n_300_m_20122        59              13   False         36
# 21  heur049_n_300_m_17695        60              11   False         45
# 22  heur050_n_300_m_19207        60              11   False         45
# 23  heur051_n_300_m_20122        60              11   False         45
# 24  heur049_n_300_m_17695        60              11   False         44
# 25  heur050_n_300_m_19207        60              11   False         44
# 26  heur051_n_300_m_20122        60              11   False         44
# 27  heur049_n_300_m_17695        59              19   False         38
# 28  heur050_n_300_m_19207        59              19   False         38
# 29  heur051_n_300_m_20122        59              19   False         38
#
#     MaxStallGenerations  tolerance  \
# 0                     5   0.016323
# 1                     5   0.016323
# 2                     5   0.016323
# 3                     3   0.034970
# 4                     3   0.034970
# 5                     3   0.034970
# 6                     1   0.059790
# 7                     1   0.059790
# 8                     1   0.059790
# 9                     5   0.027954
# 10                    5   0.027954
# 11                    5   0.027954
# 12                    3   0.062950
# 13                    3   0.062950
# 14                    3   0.062950
# 15                    1   0.059860
# 16                    1   0.059860
# 17                    1   0.059860
# 18                    1   0.022327
# 19                    1   0.022327
# 20                    1   0.022327
# 21                    1   0.060129
# 22                    1   0.060129
# 23                    1   0.060129
# 24                    1   0.021238
# 25                    1   0.021238
# 26                    1   0.021238
# 27                    2   0.020278
# 28                    2   0.020278
# 29                    2   0.020278
#
#                                                result  baseline    score  \
# 0   <helper_functions_assignment2.GA_solution obje...   51392.0  27784.0
# 1   <helper_functions_assignment2.GA_solution obje...   55846.0  35668.0
# 2   <helper_functions_assignment2.GA_solution obje...   58623.0   7065.0
# 3   <helper_functions_assignment2.GA_solution obje...   51392.0  30850.0
# 4   <helper_functions_assignment2.GA_solution obje...   55846.0  45493.0
# 5   <helper_functions_assignment2.GA_solution obje...   58623.0  32240.0
# 6   <helper_functions_assignment2.GA_solution obje...   51392.0  33844.0
# 7   <helper_functions_assignment2.GA_solution obje...   55846.0  45707.0
# 8   <helper_functions_assignment2.GA_solution obje...   58623.0   8237.0
# 9   <helper_functions_assignment2.GA_solution obje...   51392.0  31122.0
# 10  <helper_functions_assignment2.GA_solution obje...   55846.0  35752.0
# 11  <helper_functions_assignment2.GA_solution obje...   58623.0   7236.0
# 12  <helper_functions_assignment2.GA_solution obje...   51392.0  22416.0
# 13  <helper_functions_assignment2.GA_solution obje...   55846.0  35401.0
# 14  <helper_functions_assignment2.GA_solution obje...   58623.0   7283.0
# 15  <helper_functions_assignment2.GA_solution obje...   51392.0  27407.0
# 16  <helper_functions_assignment2.GA_solution obje...   55846.0  43008.0
# 17  <helper_functions_assignment2.GA_solution obje...   58623.0   8385.0
# 18  <helper_functions_assignment2.GA_solution obje...   51392.0  24217.0
# 19  <helper_functions_assignment2.GA_solution obje...   55846.0  36306.0
# 20  <helper_functions_assignment2.GA_solution obje...   58623.0   7513.0
# 21  <helper_functions_assignment2.GA_solution obje...   51392.0  33940.0
# 22  <helper_functions_assignment2.GA_solution obje...   55846.0  44432.0
# 23  <helper_functions_assignment2.GA_solution obje...   58623.0   7770.0
# 24  <helper_functions_assignment2.GA_solution obje...   51392.0  27123.0
# 25  <helper_functions_assignment2.GA_solution obje...   55846.0  37978.0
# 26  <helper_functions_assignment2.GA_solution obje...   58623.0   7522.0
# 27  <helper_functions_assignment2.GA_solution obje...   51392.0  26145.0
# 28  <helper_functions_assignment2.GA_solution obje...   55846.0  35743.0
# 29  <helper_functions_assignment2.GA_solution obje...   58623.0   6694.0
#
#        runtime instance_ID
# 0   286.402287         049
# 1   271.063177         050
# 2   299.610126         051
# 3     3.037933         049
# 4     2.465436         050
# 5     2.782868         051
# 6     3.973023         049
# 7     4.301993         050
# 8    82.960800         051
# 9   281.772841         049
# 10  272.910992         050
# 11  276.498007         051
# 12  247.669211         049
# 13  263.590445         050
# 14  329.554881         051
# 15  103.689481         049
# 16    7.560271         050
# 17  162.032818         051
# 18  202.063586         049
# 19  185.875453         050
# 20  228.121126         051
# 21   18.801383         049
# 22   18.894018         050
# 23  108.194797         051
# 24  185.770782         049
# 25   91.282414         050
# 26  179.654780         051
# 27  148.552714         049
# 28  185.489672         050
# 29  245.341535         051

# %% [markdown]
# ### get the rows with best results for each instance

# %%
results.loc[results.groupby('Instance').score.idxmin()]
# Out:
#                  Instance  pop_size  init_no_plexes  mutate  elitism_k  \
# 12  heur049_n_300_m_17695        89              25   False          5
# 13  heur050_n_300_m_19207        89              25   False          5
# 29  heur051_n_300_m_20122        59              19   False         38
#
#     MaxStallGenerations  tolerance  \
# 12                    3   0.062950
# 13                    3   0.062950
# 29                    2   0.020278
#
#                                                result  baseline    score  \
# 12  <helper_functions_assignment2.GA_solution obje...   51392.0  22416.0
# 13  <helper_functions_assignment2.GA_solution obje...   55846.0  35401.0
# 29  <helper_functions_assignment2.GA_solution obje...   58623.0   6694.0
#
#        runtime instance_ID
# 12  247.669211         049
# 13  263.590445         050
# 29  245.341535         051

# %% [markdown]
# ### save best results

# %%
for idx in results.groupby('Instance').score.idxmin():
    path = folder_path+ results.loc[idx].Instance+".txt"
    node_impact_orig, node_degree_orig, plex_assignment, edges_n1, edges_n2, edge_weights, edge_assignment_orig, s, n, m = create_problem_instance(path)
    
    write_solution(results.loc[idx].result.edge_assignment, 
                   results.loc[idx].Instance, 
                   edge_weights, 
                   edges_n1, 
                   edges_n2, 
                   algorithm = "GA")
