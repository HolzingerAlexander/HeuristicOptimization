# %%
import numpy as np
import pandas as pd
import time
import random
from typing import Callable
from matplotlib import pyplot as plt
from helper_functions import *

# %%
from os import listdir
instance_type = "inst_competition/"
outputs = []

for inst in listdir("data/"+instance_type):
    problem_instance = inst[:-4]
    print(problem_instance)
    path = "data/"+instance_type + problem_instance +".txt"
    problem = Problem(path)
    metadata = pd.read_csv(path, sep=" ", nrows=1, header=None).iloc[0]
    n = metadata.iloc[1]
    m = metadata.iloc[2]
    inital_solution = problem.get_heuristic_solution()
    print("initial score:",inital_solution.get_weight())
    
   
    start_time = time.time()
    sol, obj_traj, temp_traj, rej_traj = SA(inital_solution, 
                                            equilibrium = 50, 
                                            cooling = 0.75,
                                           T_init = int(m*0.006),
                                           stopping_criteria = "noImprovement",
                                           T_fin_frac = 4,
                                           tau = 5)
    # calculate rejection rate
    cumulative_sum = np.cumsum(rej_traj)
    time_steps = np.arange(1, len(rej_traj) + 1)
    rej_rate = cumulative_sum / time_steps
    
    print(sol.get_weight())
    output = {
        'solution': sol,
        'score': sol.get_weight(),
        'objective_trajectory': obj_traj,
        'temperature_trajectory': temp_traj,
        'rejection_trajectory': rej_traj,
        'rejection_rate': rej_rate,
        'runtime': time.time()-start_time
    }
    outputs.append(output)
    write_solution(sol.get_edges(), problem_instance, algorithm = "SA")
# Out:
# heur049_n_300_m_17695
# start
# 235.64 seconds
# initial score: 32124
# T: 106
# tmp changes since last improvment: 0
# T: 79.5
# tmp changes since last improvment: 1
# T: 59.625
# tmp changes since last improvment: 1
# T: 44.71875
# tmp changes since last improvment: 1
# T: 33.5390625
# tmp changes since last improvment: 1
# T: 25.154296875
# tmp changes since last improvment: 1
# T: 18.86572265625
# tmp changes since last improvment: 1
# T: 14.1492919921875
# tmp changes since last improvment: 1
# T: 10.611968994140625
# tmp changes since last improvment: 1
# 29253
# heur050_n_300_m_19207
# start
# 449.18 seconds
# initial score: 42729
# T: 115
# tmp changes since last improvment: 0
# T: 86.25
# tmp changes since last improvment: 1
# T: 64.6875
# tmp changes since last improvment: 2
# T: 48.515625
# tmp changes since last improvment: 3
# T: 36.38671875
# tmp changes since last improvment: 4
# T: 27.2900390625
# tmp changes since last improvment: 5
# 42729
# heur051_n_300_m_20122
# start
# 135.17 seconds
# initial score: 14241
# T: 120
# tmp changes since last improvment: 0
# T: 90.0
# tmp changes since last improvment: 1
# T: 67.5
# tmp changes since last improvment: 1
# T: 50.625
# tmp changes since last improvment: 1
# T: 37.96875
# tmp changes since last improvment: 1
# T: 28.4765625
# tmp changes since last improvment: 2
# T: 21.357421875
# tmp changes since last improvment: 3
# 13037

# %%
for idx, output in enumerate(outputs):
    print(f"Output {idx + 1}:")
    print("Score:", output['score'])
    print("runtime:", output['runtime'])
    print("-----------")
# Out:
# Output 1:
# Score: 29253
# runtime: 901.4963781833649
# -----------
# Output 2:
# Score: 42729
# runtime: 811.6125364303589
# -----------
# Output 3:
# Score: 13037
# runtime: 902.2299709320068
# -----------

# %% [markdown]
# # test instances

# %% [markdown]
# Since the information that the scores of all algorithms should also be reported in all test instances (which is very unintuiitive) was hidden in the general information, it was overlooked by us. By the time we realized the mistake, we were running out of time and decided to only run it for the competition instances and the first 10 test instances. The cell below was stopped by us, which is the reason for the error message.

# %%
from os import listdir
instance_type = "test_instances/"
outputs = []

for inst in listdir("data/"+instance_type):
    problem_instance = inst[:-4]
    print(problem_instance)
    path = "data/"+instance_type + problem_instance +".txt"
    problem = Problem(path)
    metadata = pd.read_csv(path, sep=" ", nrows=1, header=None).iloc[0]
    n = metadata.iloc[1]
    m = metadata.iloc[2]
    inital_solution = problem.get_heuristic_solution()
    print("initial score:",inital_solution.get_weight())
    
   
    start_time = time.time()
    sol, obj_traj, temp_traj, rej_traj = SA(inital_solution, 
                                            equilibrium = 50, 
                                            cooling = 0.75,
                                           T_init = int(m*0.006)+1,
                                           stopping_criteria = "noImprovement",
                                           T_fin_frac = 4,
                                           tau = 5)
    # calculate rejection rate
    cumulative_sum = np.cumsum(rej_traj)
    time_steps = np.arange(1, len(rej_traj) + 1)
    rej_rate = cumulative_sum / time_steps
    
    print(sol.get_weight())
    output = {
        'solution': sol,
        'score': sol.get_weight(),
        'objective_trajectory': obj_traj,
        'temperature_trajectory': temp_traj,
        'rejection_trajectory': rej_traj,
        'rejection_rate': rej_rate,
        'runtime': time.time()-start_time
    }
    outputs.append(output)
    #write_solution(sol.get_edges(), problem_instance, algorithm = "SA")
# Out:
# heur001_n_10_m_31
# start
# 0.2 seconds
# initial score: 41
# T: 1
# tmp changes since last improvment: 0
# T: 0.75
# tmp changes since last improvment: 1
# T: 0.5625
# tmp changes since last improvment: 1
# T: 0.421875
# tmp changes since last improvment: 2
# T: 0.31640625
# tmp changes since last improvment: 3
# T: 0.2373046875
# tmp changes since last improvment: 1
# T: 0.177978515625
# tmp changes since last improvment: 2
# T: 0.13348388671875
# tmp changes since last improvment: 3
# T: 0.1001129150390625
# tmp changes since last improvment: 4
# T: 0.07508468627929688
# tmp changes since last improvment: 5
# 32
# heur002_n_100_m_3274
# start
# 42.44 seconds
# initial score: 3825
# T: 20
# tmp changes since last improvment: 0
# T: 15.0
# tmp changes since last improvment: 1
# T: 11.25
# tmp changes since last improvment: 1
# T: 8.4375
# tmp changes since last improvment: 1
# T: 6.328125
# tmp changes since last improvment: 1
# T: 4.74609375
# tmp changes since last improvment: 1
# T: 3.5595703125
# tmp changes since last improvment: 2
# T: 2.669677734375
# tmp changes since last improvment: 1
# T: 2.00225830078125
# tmp changes since last improvment: 2
# T: 1.5016937255859375
# tmp changes since last improvment: 1
# T: 1.1262702941894531
# tmp changes since last improvment: 1
# T: 0.8447027206420898
# tmp changes since last improvment: 2
# T: 0.6335270404815674
# tmp changes since last improvment: 1
# T: 0.47514528036117554
# tmp changes since last improvment: 2
# T: 0.35635896027088165
# tmp changes since last improvment: 3
# T: 0.26726922020316124
# tmp changes since last improvment: 4
# T: 0.20045191515237093
# tmp changes since last improvment: 5
# T: 0.1503389363642782
# tmp changes since last improvment: 1
# T: 0.11275420227320865
# tmp changes since last improvment: 1
# T: 0.08456565170490649
# tmp changes since last improvment: 2
# T: 0.06342423877867986
# tmp changes since last improvment: 1
# T: 0.0475681790840099
# tmp changes since last improvment: 2
# T: 0.035676134313007424
# tmp changes since last improvment: 3
# T: 0.026757100734755568
# tmp changes since last improvment: 4
# T: 0.020067825551066676
# tmp changes since last improvment: 1
# T: 0.015050869163300007
# tmp changes since last improvment: 1
# T: 0.011288151872475005
# tmp changes since last improvment: 2
# T: 0.008466113904356254
# tmp changes since last improvment: 1
# T: 0.00634958542826719
# tmp changes since last improvment: 1
# T: 0.004762189071200393
# tmp changes since last improvment: 1
# T: 0.0035716418034002946
# tmp changes since last improvment: 2
# T: 0.002678731352550221
# tmp changes since last improvment: 1
# T: 0.0020090485144126655
# tmp changes since last improvment: 1
# T: 0.0015067863858094991
# tmp changes since last improvment: 2
# 2316
# heur003_n_120_m_2588
# start
# 45.4 seconds
# initial score: 6069
# T: 16
# tmp changes since last improvment: 0
# T: 12.0
# tmp changes since last improvment: 1
# T: 9.0
# tmp changes since last improvment: 1
# T: 6.75
# tmp changes since last improvment: 1
# T: 5.0625
# tmp changes since last improvment: 1
# T: 3.796875
# tmp changes since last improvment: 1
# T: 2.84765625
# tmp changes since last improvment: 1
# T: 2.1357421875
# tmp changes since last improvment: 1
# T: 1.601806640625
# tmp changes since last improvment: 1
# T: 1.20135498046875
# tmp changes since last improvment: 1
# T: 0.9010162353515625
# tmp changes since last improvment: 1
# T: 0.6757621765136719
# tmp changes since last improvment: 1
# T: 0.5068216323852539
# tmp changes since last improvment: 1
# T: 0.38011622428894043
# tmp changes since last improvment: 1
# T: 0.2850871682167053
# tmp changes since last improvment: 1
# T: 0.213815376162529
# tmp changes since last improvment: 1
# T: 0.16036153212189674
# tmp changes since last improvment: 2
# T: 0.12027114909142256
# tmp changes since last improvment: 1
# T: 0.09020336181856692
# tmp changes since last improvment: 1
# T: 0.06765252136392519
# tmp changes since last improvment: 1
# T: 0.05073939102294389
# tmp changes since last improvment: 1
# T: 0.03805454326720792
# tmp changes since last improvment: 1
# T: 0.02854090745040594
# tmp changes since last improvment: 1
# T: 0.021405680587804454
# tmp changes since last improvment: 2
# T: 0.01605426044085334
# tmp changes since last improvment: 1
# T: 0.012040695330640006
# tmp changes since last improvment: 1
# T: 0.009030521497980004
# tmp changes since last improvment: 2
# T: 0.006772891123485003
# tmp changes since last improvment: 1
# T: 0.005079668342613752
# tmp changes since last improvment: 1
# T: 0.0038097512569603142
# tmp changes since last improvment: 2
# T: 0.0028573134427202357
# tmp changes since last improvment: 1
# T: 0.0021429850820401768
# tmp changes since last improvment: 1
# T: 0.0016072388115301326
# tmp changes since last improvment: 1
# T: 0.0012054291086475994
# tmp changes since last improvment: 1
# 5151
# heur004_n_140_m_3014
# start
# 58.01 seconds
# initial score: 7304
# T: 19
# tmp changes since last improvment: 0
# T: 14.25
# tmp changes since last improvment: 1
# T: 10.6875
# tmp changes since last improvment: 2
# T: 8.015625
# tmp changes since last improvment: 3
# T: 6.01171875
# tmp changes since last improvment: 4
# T: 4.5087890625
# tmp changes since last improvment: 5
# 7304
# heur005_n_160_m_4015
# start
# 65.94 seconds
# initial score: 9459
# T: 25
# tmp changes since last improvment: 0
# T: 18.75
# tmp changes since last improvment: 1
# T: 14.0625
# tmp changes since last improvment: 2
# T: 10.546875
# tmp changes since last improvment: 3
# T: 7.91015625
# tmp changes since last improvment: 4
# T: 5.9326171875
# tmp changes since last improvment: 5
# 9412
# heur006_n_180_m_6067
# start
# 175.4 seconds
# initial score: 13855
# T: 37
# tmp changes since last improvment: 0
# T: 27.75
# tmp changes since last improvment: 1
# T: 20.8125
# tmp changes since last improvment: 2
# T: 15.609375
# tmp changes since last improvment: 3
# T: 11.70703125
# tmp changes since last improvment: 4
# T: 8.7802734375
# tmp changes since last improvment: 5
# 13777
# heur007_n_200_m_6731
# start
# 151.94 seconds
# initial score: 16581
# T: 41
# tmp changes since last improvment: 0
# T: 30.75
# tmp changes since last improvment: 1
# T: 23.0625
# tmp changes since last improvment: 2
# T: 17.296875
# tmp changes since last improvment: 3
# T: 12.97265625
# tmp changes since last improvment: 4
# T: 9.7294921875
# tmp changes since last improvment: 5
# 16581
# heur008_n_250_m_1045
# start
# 6.74 seconds
# initial score: 831
# T: 7
# tmp changes since last improvment: 0
# T: 5.25
# tmp changes since last improvment: 1
# T: 3.9375
# tmp changes since last improvment: 2
# T: 2.953125
# tmp changes since last improvment: 3
# T: 2.21484375
# tmp changes since last improvment: 4
# T: 1.6611328125
# tmp changes since last improvment: 5
# 825
# heur009_n_250_m_1450
# start
# 12.5 seconds
# initial score: 2265
# T: 9
# tmp changes since last improvment: 0
# T: 6.75
# tmp changes since last improvment: 1
# T: 5.0625
# tmp changes since last improvment: 2
# T: 3.796875
# tmp changes since last improvment: 3
# T: 2.84765625
# tmp changes since last improvment: 4
# T: 2.1357421875
# tmp changes since last improvment: 5
# 2265
# heur010_n_250_m_4507
# start
# 69.56 seconds
# initial score: 7047
# T: 28
# tmp changes since last improvment: 0
# T: 21.0
# tmp changes since last improvment: 1
# T: 15.75
# tmp changes since last improvment: 2
# T: 11.8125
# tmp changes since last improvment: 3
# T: 8.859375
# tmp changes since last improvment: 4
# T: 6.64453125
# tmp changes since last improvment: 5
# T: 4.9833984375
# tmp changes since last improvment: 1
# T: 3.737548828125
# tmp changes since last improvment: 1
# T: 2.80316162109375
# tmp changes since last improvment: 1
# T: 2.1023712158203125
# tmp changes since last improvment: 1
# 6793
# heur011_n_250_m_6574
# start
# 76.74 seconds
# initial score: 7348
# T: 40
# tmp changes since last improvment: 0
# T: 30.0
# tmp changes since last improvment: 1
# T: 22.5
# tmp changes since last improvment: 2
# T: 16.875
# tmp changes since last improvment: 3
# T: 12.65625
# tmp changes since last improvment: 4
# T: 9.4921875
# tmp changes since last improvment: 5
# 7348
# heur012_n_250_m_20035
# start
# 128.39 seconds
# initial score: 25090
# T: 121
# tmp changes since last improvment: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 18
#      14 print("initial score:",inital_solution.get_weight())
#      17 start_time = time.time()
# ---> 18 sol, obj_traj, temp_traj, rej_traj = SA(inital_solution,
#      19                                         equilibrium = 50,
#      20                                         cooling = 0.75,
#      21                                        T_init = int(m*0.006)+1,
#      22                                        stopping_criteria = "noImprovement",
#      23                                        T_fin_frac = 4,
#      24                                        tau = 5)
#      25 # calculate rejection rate
#      26 cumulative_sum = np.cumsum(rej_traj)
#
# File ~\Documents\Dokumente\UNI\HOT\assignment\HeuristicOptimization\helper_functions.py:1070, in SA(solution, T_init, equilibrium, cooling, stopping_criteria, T_fin_frac, tau, random_state)
#    1068 print("tmp changes since last improvment:", tmp_changes_since_last_improvement)
#    1069 while t<equilibrium:
# -> 1070     nodes, edges, weight = move1node_random(current_solution.get_nodes(),
#    1071                                 current_solution.get_edges(),
#    1072                                 current_solution.get_weight(),
#    1073                                 current_solution.get_s(), add_neg_edges = True,
#    1074                                     print_info = False)
#    1075     new_solution = Solution(nodes, edges, solution.get_s(), weight)
#    1076     if new_solution.get_weight() < current_solution.get_weight():
#
# File ~\Documents\Dokumente\UNI\HOT\assignment\HeuristicOptimization\helper_functions.py:988, in move1node_random(nodes_solution, edges_solution, score, s, add_neg_edges, print_info)
#     986 # add all edges we want to have anyway
#     987 if add_neg_edges:
# --> 988     for index, row3 in tmp_edges.iterrows():
#     989         n1 = row3.n1.item()
#     990         n2 = row3.n2.item()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1453, in DataFrame.iterrows(self)
#    1451 using_cow = using_copy_on_write()
#    1452 for k, v in zip(self.index, self.values):
# -> 1453     s = klass(v, index=columns, name=k).__finalize__(self)
#    1454     if using_cow and self._mgr.is_single_block:
#    1455         s._mgr.add_references(self._mgr)  # type: ignore[arg-type]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:425, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     422 if isinstance(data, SingleBlockManager) and using_copy_on_write() and not copy:
#     423     data = data.copy(deep=False)
# --> 425 name = ibase.maybe_extract_name(name, data, type(self))
#     427 if index is not None:
#     428     index = ensure_index(index)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7617, in maybe_extract_name(name, obj, cls)
#    7614     name = obj.name
#    7616 # GH#29069
# -> 7617 if not is_hashable(name):
#    7618     raise TypeError(f"{cls.__name__}.name must be a hashable type")
#    7620 return name
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\inference.py:334, in is_hashable(obj)
#     307     """
#     308     Check if the object is a named tuple.
#     309
#    (...)
#     329     False
#     330     """
#     331     return isinstance(obj, abc.Sequence) and hasattr(obj, "_fields")
# --> 334 def is_hashable(obj) -> TypeGuard[Hashable]:
#     335     """
#     336     Return True if hash(obj) will succeed, False otherwise.
#     337
#    (...)
#     356     False
#     357     """
#     358     # Unfortunately, we can't use isinstance(obj, collections.abc.Hashable),
#     359     # which can be faster than calling hash. That is because numpy scalars
#     360     # fail this test.
#     361
#     362     # Reconsider this decision once this numpy bug is fixed:
#     363     # https://github.com/numpy/numpy/issues/5562
#
# KeyboardInterrupt:
